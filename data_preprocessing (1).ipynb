# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\anits-csm\anaconda\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\anits-csm\anaconda\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anits-csm\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anits-csm\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anits-csm\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\anits-csm\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder,StandardScaler
data={
    'Age':[25,30,np.nan,35,28],
'Salary':[50000,60000,58000,np.nan,52000],
'Gender':['Male','Female','Female','Male','Female'],
'Purchased':['Yes','No','Yes','No','Yes']
}
df=pd.DataFrame(data)
print("Original Dataset")
print(df)
imputer=SimpleImputer(strategy='mean')
df[['Age','Salary']]=imputer.fit_transform(df[['Age','Salary']])
print("\nDataset after Handling Missing Values")
print(df)
encoder=LabelEncoder()
df['Gender']=encoder.fit_transform(df['Gender'])
df['Purchased']=encoder.fit_transform(df['Purchased'])
print("\nDataset after Encoding")
print(df)
scaler=StandardScaler()
df[['Age','Salary']]=scaler.fit_transform(df[['Age','Salary']])
print("\nDataset after Feature Scaling")
print(df)
# Out:
# Original Dataset
#     Age   Salary  Gender Purchased
# 0  25.0  50000.0    Male       Yes
# 1  30.0  60000.0  Female        No
# 2   NaN  58000.0  Female       Yes
# 3  35.0      NaN    Male        No
# 4  28.0  52000.0  Female       Yes
#
# Dataset after Handling Missing Values
#     Age   Salary  Gender Purchased
# 0  25.0  50000.0    Male       Yes
# 1  30.0  60000.0  Female        No
# 2  29.5  58000.0  Female       Yes
# 3  35.0  55000.0    Male        No
# 4  28.0  52000.0  Female       Yes
#
# Dataset after Encoding
#     Age   Salary  Gender  Purchased
# 0  25.0  50000.0       1          1
# 1  30.0  60000.0       0          0
# 2  29.5  58000.0       0          1
# 3  35.0  55000.0       1          0
# 4  28.0  52000.0       0          1
#
# Dataset after Feature Scaling
#         Age    Salary  Gender  Purchased
# 0 -1.382164 -1.355815       1          1
# 1  0.153574  1.355815       0          0
# 2  0.000000  0.813489       0          1
# 3  1.689312  0.000000       1          0
# 4 -0.460721 -0.813489       0          1

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
data={
    'Age':[25,30,np.nan,35,28],
'Salary':[50000,60000,58000,np.nan,52000],
'Gender':['Male','Female','Female','Male','Female'],
'Purchased':['Yes','No','Yes','No','Yes']
}

# %%
df=pd.DataFrame(data)
print("Original Dataset")
print(df)
# Out:
# Original Dataset
#     Age   Salary  Gender Purchased
# 0  25.0  50000.0    Male       Yes
# 1  30.0  60000.0  Female        No
# 2   NaN  58000.0  Female       Yes
# 3  35.0      NaN    Male        No
# 4  28.0  52000.0  Female       Yes

# %%
imputer=SimpleImputer(strategy='mean')
df[['Age','Salary']]=imputer.fit_transform(df[['Age','Salary']])
print("\nDataset after Handling Missing Values")
print(df)
# Out:
# Dataset after Handling Missing Values
#     Age   Salary  Gender Purchased
# 0  25.0  50000.0    Male       Yes
# 1  30.0  60000.0  Female        No
# 2  29.5  58000.0  Female       Yes
# 3  35.0  55000.0    Male        No
# 4  28.0  52000.0  Female       Yes

# %%
encoder=LabelEncoder()
df['Gender']=encoder.fit_transform(df['Gender'])
df['Purchased']=encoder.fit_transform(df['Purchased'])
print("\nDataset after Encoding")
print(df)
# Out:
# Dataset after Encoding
#     Age   Salary  Gender  Purchased
# 0  25.0  50000.0       1          1
# 1  30.0  60000.0       0          0
# 2  29.5  58000.0       0          1
# 3  35.0  55000.0       1          0
# 4  28.0  52000.0       0          1

# %%
scaler=StandardScaler()
df[['Age','Salary']]=scaler.fit_transform(df[['Age','Salary']])
print("\nDataset after Feature Scaling")
print(df)
# Out:
# Dataset after Feature Scaling
#         Age    Salary  Gender  Purchased
# 0 -1.382164 -1.355815       1          1
# 1  0.153574  1.355815       0          0
# 2  0.000000  0.813489       0          1
# 3  1.689312  0.000000       1          0
# 4 -0.460721 -0.813489       0          1
