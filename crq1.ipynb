# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
data ={
    'STUDENTS' :['A','B','C','D','E'],
    'STUDYHOURS':[2,4,5,7,9],
    'EXAMHOURS':[3,5,8,10,12]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#   STUDENTS  STUDYHOURS  EXAMHOURS
# 0        A           2          3
# 1        B           4          5
# 2        C           5          8
# 3        D           7         10
# 4        E           9         12

# %%
X = df[['STUDYHOURS']]
y = df['EXAMHOURS']

# %%
print(X.shape)
print(y)
# Out:
# (5, 1)
# 0     3
# 1     5
# 2     8
# 3    10
# 4    12
# Name: EXAMHOURS, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaler=scaler.fit_transform(X)

# %%
pca=PCA(n_components=1)
X_pca=pca.fit_transform(X_scaler)
print(pca.explained_variance_ratio_)
# Out:
# [1.]
